# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as ply
import seaborn as sns

from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\HP\Documents\python sanjana\EDA\pcos_rotterdam_balanceado.csv")
df.head()
# Out:
#    Age   BMI  Menstrual_Irregularity  Testosterone_Level(ng/dL)  \
# 0   29  21.2                       0                       46.1
# 1   20  20.5                       0                       59.4
# 2   23  23.1                       0                       69.3
# 3   19  32.7                       1                       77.7
# 4   19  25.9                       0                       49.4
#
#    Antral_Follicle_Count  PCOS_Diagnosis
# 0                      9               0
# 1                      6               0
# 2                     10               0
# 3                     37               1
# 4                      5               0

# %%
df.shape
# Out:
# (3000, 6)

# %% [markdown]
# Data Cleaning

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, BMI, Menstrual_Irregularity, Testosterone_Level(ng/dL), Antral_Follicle_Count, PCOS_Diagnosis]
# Index: []

# %% [markdown]
# Check for Null values

# %%
df.isnull().sum()
# Out:
# Age                          0
# BMI                          0
# Menstrual_Irregularity       0
# Testosterone_Level(ng/dL)    0
# Antral_Follicle_Count        0
# PCOS_Diagnosis               0
# dtype: int64

# %%
sns.heatmap(df.isnull()) # shows if there are null values
# Out:
# <Axes: >

# %%
# checking for data types 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        3000 non-null   int64
#  1   BMI                        3000 non-null   float64
#  2   Menstrual_Irregularity     3000 non-null   int64
#  3   Testosterone_Level(ng/dL)  3000 non-null   float64
#  4   Antral_Follicle_Count      3000 non-null   int64
#  5   PCOS_Diagnosis             3000 non-null   int64
# dtypes: float64(2), int64(4)
# memory usage: 140.8 KB

# %%
# checking for unique values
for i in df.columns:
    print(f'Column Name : {i}','\n')
    print(df[i].unique(),'\n')
    print(f'Number of unique values=',df[i].nunique(),'\n')
# Out:
# Column Name : Age
#
# [29 20 23 19 21 26 25 31 40 18 43 30 35 27 24 28 22 33 44 38 32 36 37 41
#  42 39 34]
#
# Number of unique values= 27
#
# Column Name : BMI
#
# [21.2 20.5 23.1 32.7 25.9 20.6 25.3 25.2 25.7 29.  22.4 24.7 23.  23.7
#  28.8 23.5 23.8 28.2 23.2 23.9 20.8 31.6 19.4 25.6 24.1 31.3 26.  20.7
#  21.  26.5 27.4 30.6 22.3 35.4 15.1 32.8 27.7 28.6 31.5 22.5 18.2 23.3
#  23.4 15.2 21.8 26.8 20.9 24.3 20.2 29.2 25.8 15.8 26.2 28.1 25.5 29.4
#  26.9 27.8 22.1 18.4 21.6 32.4 18.1 21.1 18.7 28.3 27.9 20.4 21.3 24.
#  18.  19.3 41.9 21.5 19.8 21.4 19.5 24.2 20.3 24.5 31.2 19.  17.2 30.1
#  21.9 27.6 27.5 16.5 17.1 13.5 36.1 17.8 18.3 22.7 33.4 33.8 16.2 22.2
#  23.6 34.6 30.3 32.1 22.8 17.7 18.6 37.6 19.9 18.5 27.  17.6 26.3 26.7
#  14.2 25.1 24.6 20.1 13.  29.8 31.7 25.4 24.8 14.6 28.9 25.  19.6 16.4
#  29.5 22.9 24.4 28.4 27.2 27.1 24.9 17.9 18.9 13.1 19.7 31.9 18.8 12.3
#  26.1 16.1 29.6 34.  19.1 22.  29.3 26.6 32.5 14.1  9.8 28.5 31.  32.3
# ...

# %%
# Checking for Summary Statistics
df.describe()
# Out:
#                Age          BMI  Menstrual_Irregularity  \
# count  3000.000000  3000.000000             3000.000000
# mean     30.052667    23.646000                0.289333
# std       7.549982     4.510006                0.453529
# min      18.000000     8.500000                0.000000
# 25%      24.000000    20.800000                0.000000
# 50%      30.000000    23.400000                0.000000
# 75%      36.000000    26.300000                1.000000
# max      44.000000    44.700000                1.000000
#
#        Testosterone_Level(ng/dL)  Antral_Follicle_Count  PCOS_Diagnosis
# count                3000.000000            3000.000000     3000.000000
# mean                   57.228267              10.732333        0.200000
# std                    18.171066               8.471478        0.400067
# min                    20.500000               3.000000        0.000000
# 25%                    45.200000               5.000000        0.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Histogram for all numerical features
df.hist(figsize=(15, 12), bins=20, edgecolor='black')
plt.tight_layout()
plt.show()

# Boxplot 
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, orient='h')
plt.title("Boxplot of Numeric Features")
plt.show()

# %%
# Checking correlation 
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
#plirplot
features = df.columns[:5] 
sns.pairplot(df[features])

# %%
import seaborn as sns

# %%
print(df.columns.tolist())
# Out:
# ['Age', 'BMI', 'Menstrual_Irregularity', 'Testosterone_Level(ng/dL)', 'Antral_Follicle_Count', 'PCOS_Diagnosis']

# %%
df.head()
# Out:
#    Age   BMI  Menstrual_Irregularity  Testosterone_Level(ng/dL)  \
# 0   29  21.2                       0                       46.1
# 1   20  20.5                       0                       59.4
# 2   23  23.1                       0                       69.3
# 3   19  32.7                       1                       77.7
# 4   19  25.9                       0                       49.4
#
#    Antral_Follicle_Count  PCOS_Diagnosis
# 0                      9               0
# 1                      6               0
# 2                     10               0
# 3                     37               1
# 4                      5               0

# %%
# Distribution of the target
sns.countplot(data=df, x='PCOS_Diagnosis')
plt.title("PCOS Class Distribution")
plt.show()

# Boxplot of a feature vs target
sns.boxplot(x='PCOS_Diagnosis', y='BMI', data=df)
plt.title("BMI vs PCOS")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split


X = df.drop('PCOS_Diagnosis', axis=1)
y = df['PCOS_Diagnosis']


X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

model = RandomForestClassifier()
model.fit(X_train, y_train)


importances = pd.Series(model.feature_importances_, index=X.columns)
importances.sort_values(ascending=False).plot(kind='bar', figsize=(12,6), title='Feature Importance')
# Out:
# <Axes: title={'center': 'Feature Importance'}>
